# %% [markdown]
# # Modeling the Gravitational Slingshot Effect
# ### Sam Cochran, Jacob Murri Caleb Wilson

# %% [markdown]
# This jupyter notebook contains the code that runs our simulation and generates our plots and animations.  We have commented out the animation code, since it takes a long time to run and our animations can be found easily using the second link below.  We also note that we import code from two .py files we wrote, which can be found submitted with this file, or through the first link below.
#
# Code is here:
# https://github.com/samcochran/Gravitational-Slingshot
#
# Animations are here:
# https://samcochran.github.io/Gravitational-Slingshot/

# %%
# Import packages
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import style, rcParams
import matplotlib.animation as animation
#might want 3D stuff later
#from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import solve_ivp

#Import in-house code
from simulation import *
from plotting import *

style.use('seaborn')
rcParams['figure.figsize'] = 10, 10

# %% [markdown]
# ## 2.1 Initial Models
#
# Below are our initial trial and error efforts to produce slingshot maneuvers.

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 25
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 0, 0, 0, # Position 3
                 .35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 .3, -.3, 0]) # Velocity 3 

# Solve the system
sol = solve_ivp(gravity_acceleration, (t0, tf), init, t_eval= np.linspace(t0, tf, 10000)).y

plot_sol3d(sol, 'Messy Trajectory, Near Collision', lim=(-2, 2))
#animate_sol3d(sol, 'Messy Trajectory, Near Collision', 'messy', skip=40, lim=(-4, 4))

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/messy.mp4" controls></video>

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 10
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 0, 0, 0, # Position 3
                 .35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 .3, -.6, 0]) # Velocity 3 

# Solve the system
sol = solve_ivp(gravity_acceleration, (t0, tf), init, t_eval= np.linspace(t0, tf, 10000)).y

#BTW I don't think its non-differentiable I think it just looks like that from this scale, but I could be wrong
title = 'Non-Differentiable Trajectory \n(third body comes to a stop and changes direction)'
plot_sol3d(sol, title, lim=(-2, 2))
#animate_solution(sol, title, 'jagged', skip=40)

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/jagged.mp4" controls></video>

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 10
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 0, 0, 0, # Position 3
                 .35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 .01, -.01, 0]) # Velocity 3 

# Solve the system
sol = solve_ivp(gravity_acceleration, (t0, tf), init, t_eval= np.linspace(t0, tf, 10000)).y

title = 'Close Failure (slingshots, but curves back in)'
plot_sol3d(sol, title, lim=(-2, 2))
#animate_solution(sol, title, 'close', skip=40)

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/close.mp4" controls></video>

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 10
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 0, 0, 0, # Position 3
                 .35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 0, -.7, 0]) # Velocity 3 

# Solve the system
sol = solve_ivp(gravity_acceleration, (t0, tf), init, t_eval= np.linspace(t0, tf, 10000)).y

title = 'Tron Lightbike Maneuver (purple cuts off green)'
plot_sol3d(sol, title, lim=(-2, 2))
#animate_solution(sol, title, 'tron', skip=40)

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/tron.mp4" controls></video>

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 1
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 0, 0, 0, # Position 3
                 .35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 2, 1, 0]) # Velocity 3 

# Solve the system
sol = solve_ivp(gravity_acceleration, (t0, tf), init, t_eval= np.linspace(t0, tf, 10000)).y

plot_sol3d(sol, 'Early Slingshot Attempt', lim=(-2, 2))
#animate_solution(sol, 'Best Slingshot Attempt', 'best_attempt', skip=40)

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/best_attempt.mp4" controls></video>

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 1.75
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 0, 0, -.1, # Position 3
                 .35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 2.5, 1.25, .1]) # Velocity 3 

# Solve the system
sol = solve_ivp(gravity_acceleration, (t0, tf), init, t_eval= np.linspace(t0, tf, 10000)).y

plot_sol3d(sol, 'Slingshot Escape', lim=(-2, 2))
#animate_solution(sol, 'Slingshot Escape', 'escape', skip=40)

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/escape.mp4" controls></video>

# %% [markdown]
# This is the closest we could get to a successful slingshot maneuver on this first attempt.  We came by this mostly by trial and error.  Though we have a long way to go, we note that the third body does indeed gain velocity and change direction by passing very close to the first body, so this is a solid initial model and illustrates our goal.
#
# We further note that this is a very simple toy problem, with the first two primary bodies having mass of unity and the third body being considered as massless, so the masses, velocities, and positions for this model are pretty much meaningless, and only give us information relative to this model.
#
# Interestingly, we added a small z perturbation, and the trajectory was still a slingshot.

# %% [markdown]
# ## 2.2 Finding our First Good Slingshots
#
# We now do a sort of grid search idea to really find an optimal slingshot trajectory.

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 10
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 .25, .25, 0, # Position 3
                 .35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 2, .5, 0]) # Velocity 3 

# Solve the system for each grid point, sort of
perturb = np.zeros_like(init)
perturb[[15, 16]] = .05
fig, ax = plt.subplots()
sols = []
for k in range(20):
    sol = solve_ivp(gravity_acceleration, (t0, tf), init + k*perturb, t_eval= np.linspace(t0, tf, 10000)).y
    sols.append(sol)
    plot_solution(sol, 'Clean Slingshot Options', ax = ax, show_speed=False)
    ax.legend([])
#animate_solution(sols, "Clean Slingshot Options", "clean_options", show_speed=False)

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/clean_options.mp4" controls></video>

# %% [markdown]
# As we can see, with these higher starting velocities, the problem appears quite stable.  See the plot below however to note the chaotic behavior that appears with lower starting velocities.  If the velocity is not great enough, slight changes to initial conditions result in drastically different behavior, with some slingshotting down as we would like, and others looping around unpredictably.  This is perhaps something to keep in mind as we proceed, especially as we consider what realistic velocities for spacecraft are relative to the planetary bodies.  We might need the model to be more robust to lower velocities, depending on what the engineering constraints are for realistic spacecraft speeds.
#
# An animation of this plot can be found on our github (link at the top).

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 10
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 .25, .25, 0, # Position 3
                 .35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 .7, .3, 0]) # Velocity 3 

# Solve the system for each grid point, sort of
perturb = np.zeros_like(init)
perturb[[15, 16]] = .05
fig, ax = plt.subplots()
sols = []
for k in range(10):
    sol = solve_ivp(gravity_acceleration, (t0, tf), init + k*perturb, t_eval= np.linspace(t0, tf, 10000)).y
    sols.append(sol)
    plot_solution(sol, 'Chaotic Trajectories after small Velocity Perturbations', ax = ax, show_speed=False)
    ax.legend([])
#animate_solution(sols, "Chaotic Trajectories", "chaotic_traj", show_speed=False)

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/chaotic_traj.mp4" controls></video>

# %% [markdown]
# ## 2.4 Rotational Coordinates
#
# Below is the code that puts our plot into rotating coordinates/plots it in 3D.  Note that the functions that accomplish this are found in simulation.py and plotting.py.

# %%
# Set up initial conditions and parameters (Modified from "Best Attempt")
t0 = 0
tf = 10
init = np.array([1, 1, 0, # Position 1
                 -1, -1, 0, # Position 2
                 0, 0, -0.2, # Position 3
                 0.35, -.25, 0, # Velocity/Momentum 1
                 -.35, .25, 0, # Velocity/Momentum 2
                 2.5, 1.3, 0.2]) # Velocity 3 

# Solve the system
sol = solve_ivp(gravity_acceleration, (t0, tf), init, t_eval= np.linspace(t0, tf, 10000)).y
rot_sol, center = to_rotational(sol)
energies = massless_energy(sol, [1,1,0])

title = 'Slingshot escape (rotated)'
plot_sol3d(rot_sol, title, savefile='slingshot_escape_rotated.pdf')
plot_nbody3d(sol, "3-body Slingshot escape", energies=energies, savefile='three_body_escape_rotated.pdf')

#animate_sol3d(rot_sol, title, "slingshot3d_rotated")
#animate_nbody3d(sol, "3-body Slingshot esape", "slingshot3d", energies=energies)

# %% [markdown]
# Use this code to embed the animations:
#
#     <video src="../Animations/slingshot3d_rotated.mp4" controls></video>
#     <video src="../Animations/slingshot3d.mp4" controls></video>

# %% [markdown]
# ## 2.5 Modeling a System with Realistic Masses
#
# Both of the models below use realistic primary masses.  The basic model still assumes a zero mass third body, while the general model gives the third body a small positive mass.

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 1
init = np.array([-.09, 0, 0, # Position 1
                 1, 0, 0, # Position 2
                 .5, -.25, 0, # Position 3
                 0, -.09, 0, # Velocity/Momentum 1
                 0, 1, 0, # Velocity/Momentum 2
                 2.5, 2, 0]) # Velocity 3 

# Solve the system
sol = simulate_mechanics(init, (t0, tf), t_eval=np.linspace(t0, tf, 1000), mass_ratio=.09)

# Plot and animate
fig, ax = plt.subplots()
plot_solution(sol, 'Solar System Basic ', ax=ax)
ax.set_xlim(-2, 4)
ax.set_ylim(-2, 4)
plt.savefig('./../Plots/ss_basic.pdf')
plt.show()

plt.ioff()
#animate_solution(sol, 'Solar System Basic', 'solar_system_basic', skip=5, lim=(-2, 4), show_quivers=False, interval=30)
plt.close()

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/solar_system_basic.mp4" controls></video>

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 1
init = np.array([-.09, 0, 0, # Position 1
                 1, 0, 0, # Position 2
                 .5, -.25, 0, # Position 3
                 0, -.09, 0, # Velocity/Momentum 1
                 0, 1, 0, # Velocity/Momentum 2
                 2.5, 2, 0]) # Velocity 3 

# Solve the system
sol = simulate_mechanics_general(init, (t0, tf), t_eval=np.linspace(t0, tf, 1000), m = [1, .09, .0001])

# Plot and animate
fig, ax = plt.subplots()
plot_solution(sol, 'Solar System General', ax=ax, savefile='ss_gen.pdf')
ax.set_xlim(-2, 4)
ax.set_ylim(-2, 4)
plt.show()

plt.ioff()
#animate_solution(sol, 'Solar System General', 'solar_system_general', skip=5, lim=(-2, 4), show_quivers=False, interval=30)
plt.close()

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/solar_system_general.mp4" controls></video>

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 1
init = np.array([-.09, 0, 0, # Position 1
                 1, 0, 0, # Position 2
                 .5, -.25, 0, # Position 3
                 0, -.09, 0, # Velocity/Momentum 1
                 0, 1, 0, # Velocity/Momentum 2
                 2.5, 2, 0]) # Velocity 3 

# Solve the system
sol = simulate_mechanics(init, (t0, tf), t_eval=np.linspace(t0, tf, 1000), mass_ratio=.09)
sol_gen = simulate_mechanics_general(init, (t0, tf), t_eval=np.linspace(t0, tf, 1000), m = [1, .09, .001])

# Plot and animate
fig, ax = plt.subplots()
plot_solution(sol, 'Solar System Basic vs. General', ax=ax)
plot_solution(sol_gen, 'Solar System Basic vs. General', ax=ax)
ax.set_xlim(-2, 4)
ax.set_ylim(-2, 4)
ax.legend([])
plt.savefig(f"../Plots/ss_basic_and_general.pdf")
plt.show()

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 1
init = np.array([-.09, 0, 0, # Position 1
                 1, 0, 0, # Position 2
                 .5, -.25, 0, # Position 3
                 0, -.09, 0, # Velocity/Momentum 1
                 0, 1, 0, # Velocity/Momentum 2
                 2.5, 2, 0]) # Velocity 3 

# Solve the system for each perturbation
fig, ax = plt.subplots()
perturb = np.zeros_like(init)
perturb[[15, 16]] = 1
sols = []
for pert in [-1, -.5, -.1, -.01, 0, .01, .1, .5, 1]:
    init_new = init + perturb * pert
    sol = simulate_mechanics_general(init_new, (t0, tf), t_eval=np.linspace(t0, tf, 1000), m = [1, .09, .0001])
    sols.append(sol)
    plot_solution(sol, 'Solar System General with Initial Velocity Perturbations', ax=ax)
    ax.set_xlim(-2, 4)
    ax.set_ylim(-2, 4)
plt.legend([])
plt.savefig(f"../Plots/ss_gen_options.pdf")
plt.show()

#animate_solution(sols, "Solar system general with perturbed velocities", "ss_gen_options")

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/ss_gen_options.mp4" controls></video>

# %% [markdown]
# ## 2.6  Automating the Search for Slingshot-Producing Initial Conditions

# %%
# Set up initial conditions and parameters
t0 = 0
tf = 1
N = 1000
init = np.array([-.09, 0, 0, # Position 1
                 1, 0, 0, # Position 2
                 .5, -.25, 0, # Position 3
                 0, -.09, 0, # Velocity/Momentum 1
                 0, 1, 0, # Velocity/Momentum 2
                 2.5, 2, 0]) # Velocity 3 

### Goal is the point we want our slingshot to pass through ###
goal = np.array([1.5, 2, 0])

# Use the guide function (in simulation.py) to produce ICs that go through goal
init = guide(goal, init, t0, tf, N, m = [1, .09, .0001]) 

# Solve the system
sol = simulate_mechanics_general(init, (t0, tf), t_eval=np.linspace(t0, tf, N), m = [1, .09, .0001])

# Plot and animate
plot_solution(sol, 'Goal: pass through ' + str(tuple(goal[:-1])), lim=(-1, 2))

plt.ioff()
# animate_solution(sol, 'Goal: pass through ' + str(tuple(goal[:-1])), 'guided3', skip=10, lim=(-1, 2), show_quivers=False, interval=80)
plt.close()

# %% [markdown]
# Use this code to embed the animation:
#
#     <video src="../Animations/guided3.mp4" controls></video>
